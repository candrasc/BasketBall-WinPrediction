# %% [markdown]
# # Using a neural network on our preprocessed data to achieve even better results

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import make_scorer

import pickle as pkl
import pandas as pd
pd.set_option('display.max_columns',None)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
#Read in preprocessed data from our log reg notebook
df_exp = pd.read_csv(r'C:\Users\charl\Python\GitHub Projects\BasketBall-WinPrediction\data\NBA_game_data_exp.csv')

# %%
df_exp.iloc[300:303]
# Out:
#      Unnamed: 0   GAME_ID  TEAM_ID_home TEAM_ABBREVIATION_home ABV_HOME_home  \
# 300         320  11700020    1610612749                    MIL           MIL
# 301         321  11700022    1610612747                    LAL           LAL
# 302         322  11700023    1610612742                    DAL           DAL
#
#       FGM_home   FGA_home  FG_PCT_home  FG3M_home  FG3A_home  FG3_PCT_home  \
# 300  34.016776  80.103385     4.847811   6.543837  17.093767      2.646167
# 301  37.576434  85.144029     5.333894   6.635210  18.414309      2.473528
# 302  31.314654  75.841034     6.500546   8.638772  27.878244      2.719505
#
#       FTM_home   FTA_home  OREB_home  DREB_home   REB_home   AST_home  \
# 300  16.934472  24.265614  11.902976  34.451397  46.354373  22.192953
# 301  17.703837  25.252562  10.297015  32.820852  43.117867  24.221100
# 302  29.478669  40.052912  12.371652  30.171182  42.542834  18.146565
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df_exp.corr(), center = 0, cmap = 'PiYG')
# Out:
# <AxesSubplot:>

# %%
df_exp.dropna(inplace=True)

# %%
df_exp.head()
# Out:
#    Unnamed: 0   GAME_ID  TEAM_ID_home TEAM_ABBREVIATION_home ABV_HOME_home  \
# 0           8  11400010    1610612758                    SAC           SAC
# 1          15  11400018    1610612740                    NOP           NOP
# 2          18  11400023    1610612745                    HOU           HOU
# 3          19  11400024    1610612757                    POR           POR
# 4          20  11400025    1610612765                    DET           DET
#
#     FGM_home   FGA_home  FG_PCT_home  FG3M_home  FG3A_home  FG3_PCT_home  \
# 0  30.000000  64.000000     5.414000   5.000000  13.000000      1.900000
# 1  35.764706  78.156863     6.869255  13.803922  31.686275      4.161765
# 2  36.000000  78.000000     6.025000  10.000000  26.000000      2.636000
# 3  28.000000  81.000000     4.759000   3.000000  19.000000      0.900000
# 4  39.000000  94.000000     3.786000  11.000000  32.000000      2.625000
#
#     FTM_home   FTA_home  OREB_home  DREB_home   REB_home   AST_home  \
# ...

# %%
#Define Data
#Need to do train_test_split and test the model 

x = df_exp.loc[:,'FGM_home':'PLUS_MINUS_away'].values
y = df_exp['HOME_TEAM_WINS'].values

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.1)

# %% [markdown]
# #### Here I define a simple function to build a keras sequential model. I also set a default learning rate so that I can wrap it as an sklearn estimator later

# %%
def build_model(learning_rate = 0.001):
    model = Sequential()
    input_dim = x.shape[1]
    
    model.add(Dense(12, activation='relu', input_dim = input_dim))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(4, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    optimizer = keras.optimizers.Adam(learning_rate = learning_rate)
    
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %% [markdown]
# #### We are now going to use the KerasClassifier wrapper to turn our neural net into a sklearn estimator. We will then be able to pass it as an estimator in gridsearch to find our best hyperparameters.
#
# #### We will also create a custom sklearn scorer so that we can gridsearch based on AUC rather than accuracy

# %%
estimator = KerasClassifier(build_fn = build_model)

# %%
def custom_auc(y_test, y_hat):
    return roc_auc_score(y_test,y_hat)

auc_scoring = make_scorer(custom_auc, greater_is_better=True, needs_proba=True)

# %%
param_grid = {
    'learning_rate' : [0.1,0.001,0.0001],
    'batch_size' : [64,128,256,512],
    'epochs' : [50,150,500]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(estimator = estimator,
                    param_grid = param_grid,
                    scoring = auc_scoring,
                    cv = 3,
                    verbose = 0,
                    n_jobs = 1
                   )

# %%
grid_results = grid.fit(x_train,y_train, verbose = 0)

# %%
best_params = grid_results.best_params_
best_params
# Out:
# {'batch_size': 64, 'epochs': 150, 'learning_rate': 0.001}

# %%
print('Best AUC:', grid_results.best_score_)
# Out:
# Best AUC: 0.7027256997426129

# %% [markdown]
# #### Now that we know our best parameters, let's retrain the model as a standard keras model so that we can access its history and create some useful plots

# %%
best_model = build_model(learning_rate = best_params['learning_rate'])

# %%
history = best_model.fit(x_train,y_train, 
                         epochs = best_params['epochs'],
                         batch_size = best_params['batch_size'])
# Out:
# Train on 18998 samples
# Epoch 1/150
# 18998/18998 [==============================] - 2s 114us/sample - loss: 0.6228 - accuracy: 0.6472
# Epoch 2/150
# 18998/18998 [==============================] - 1s 55us/sample - loss: 0.6149 - accuracy: 0.6627
# Epoch 3/150
# 18998/18998 [==============================] - 1s 49us/sample - loss: 0.6152 - accuracy: 0.6604
# Epoch 4/150
# 18998/18998 [==============================] - 1s 48us/sample - loss: 0.6145 - accuracy: 0.6616
# Epoch 5/150
# 18998/18998 [==============================] - 1s 48us/sample - loss: 0.6137 - accuracy: 0.6667
# Epoch 6/150
# 18998/18998 [==============================] - 1s 49us/sample - loss: 0.6138 - accuracy: 0.6622
# Epoch 7/150
# 18998/18998 [==============================] - 1s 49us/sample - loss: 0.6130 - accuracy: 0.6642
# Epoch 8/150
# 18998/18998 [==============================] - 1s 48us/sample - loss: 0.6133 - accuracy: 0.6629
# Epoch 9/150
# ...

# %%
loss_history = history.history['loss']
acc_history = history.history['accuracy']

fig, ax = plt.subplots(2,1,figsize = (15,10))

plt.subplot(2,1,1)
plt.plot(range(len(loss_history)),loss_history)
plt.title("Training Loss per Epoch")

plt.subplot(2,1,2)
plt.plot(range(len(acc_history)),acc_history)
plt.title("Accuracy per Epoch")
# Out:
# Text(0.5, 1.0, 'Accuracy per Epoch')

# %%
y_hat = best_model.predict(x_test)

# %%
y_hat_bin = np.where(y_hat>=0.5,1,0)

# %%
from sklearn.metrics import accuracy_score

print('Our Accuracy Score is: ',accuracy_score(y_test, y_hat_bin))
# Out:
# Our Accuracy Score is:  0.6778777830412127

# %%
from sklearn.metrics import classification_report, confusion_matrix

cfn_matrix1 = confusion_matrix(y_test, y_hat_bin, labels = [0,1])
cfn_report1 = classification_report(y_test, y_hat_bin)

sns.heatmap(cfn_matrix1, annot=True, fmt = 'd', cmap="Blues").set_title('Confusion Matrix Heatmap')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')

print(cfn_report1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.48      0.55       855
#            1       0.70      0.81      0.75      1256
#
#     accuracy                           0.68      2111
#    macro avg       0.67      0.65      0.65      2111
# weighted avg       0.67      0.68      0.67      2111

# %%
from sklearn.metrics import roc_auc_score

AUC = roc_auc_score(y_test, y_hat)

print('Our AUC is: ',AUC)
# Out:
# Our AUC is:  0.7169017953588855

# %% [markdown]
# ### Results:
# - Our model has improved across accuracy, AUC, and precision and recall from our log reg classifier

# %%
best_model.save("my_model")
# Out:
# WARNING:tensorflow:From C:\Users\charl\anaconda3\envs\tensorflow_env\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: my_model\assets
